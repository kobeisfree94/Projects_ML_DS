# %% [markdown]
# <a href="https://colab.research.google.com/github/kobeisfree94/Projects/blob/master/README_kor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 프로젝트 이름 -- 코로나19 백신/사망률 분석
#
# 시작 날짜 -- Jan 2022
#
# requirements

# %% [markdown]
# 1. 프로젝트 개요

# %% [markdown]
# 코로나 19는 2019년 11월 부터 시작되서 전세계적으로 (2022.06.08 기준)
# - 총 확진 케이스 532M
# - 총 사망 케이스 6.3M 발생
#
# 전 세계에서 가장 처음 백신을 2020.12.08일 부터 영국에서 접종 시작을 함

# %% [markdown]
# 2. 프로젝트 배경 및 목적

# %% [markdown]
# - 전 세계적으로 코로나19 확진자수가 가장 높은 Top10 나라들의 데이터를 시각화
# - Top10 나라들을 기준으로 백신 접종이 확진률과 사망률에 어떤 여향을 끼치는지 분석

# %% [markdown]
# 3. 프로젝트 수행 절차

# %% [markdown]
# - Kaggle 데이터 (링크 추가) -- 2020.01 ~ 2021.05

# %% [markdown]
# 4. 방법 설명

# %% [markdown]
# 코로나 19 확진자 수 Top 10 나라

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 미국, 인도, 브라질, 프랑스, 러시아, 터키, 영국, 이태리, 스페인, 독일 순으로 전체 인구가 백만이 넘는 나라 중에서 가장 많은 확진자들을 배출해낸 나라들이다.
#
# 그 중에 미국이 31,991,750으로 압도적으로 많으며 인도와 브라질이 16,610,481 그리고 14,237,078로 2위와 3위를 했다. 중국이 아마 훨씬 많은 확진자들이 있을거라고 예상해보지만 정확한 통계를 얻기에는 어려웠지 않았나 싶다.

# %% [markdown]
# 5. 결과

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2020년 12월 8일날 영국에서 첫번째 코로나19 백신이 접종 되었다.
# 파란색은 각 날짜 마다 전체 확진자 수 이고 초록색은 전체 인구에서 백신을 맞은 접종률이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 두번째 그래프는 백신 접종률과 그 날 사망자의 상관관계를 보여준다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위 그림은 백신 접종률과 Intensive Care를 받은 사람들의 상관관계이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위 그림은 백신 접종률과 병원에 입원한 인원 수의 상관관계이다.

# %% [markdown]
# 위에 그림들을 보며는 백신을 처음 접종하기 시작한 2020년 12월 경 부터 백신 접종률은 올라가는 반면 확진자/입원자/사망자수가 현저히 떨어지는것을 볼수가 있다. 특히 2021년 2월에서 3월에는 ICU와 입원자 숫자가 최저를 찍는것을 볼수 있다.
#
# 하지만 신기한것은 사망자 수는 2021년 1월 부터 3월까지 잠시 하락한것을 제외 하고는 다시 올라가는것을 볼수 있다. 물론 확진자/입원자/ICU 숫자와 비교해 많이 낮기 때문에 (사망자 그래프는 500명 단위/ 나머지는 천에서 만명 단위) 실제 그래프를 똑같이 scale하면 크게 유의미한 데이터는 아닐수도 있다는 생각이 든다.
#
# 확진자 수 역시 백신 접종을 시작하고 나서 폭락한것을 볼수 있다. 그러나 2021년 4월에 다시 확진자 수가 확 올라가는것을 관찰할수 있다.
#
# 이는 다름 아닌 2021년 05월 부터 delta variant가 전세계로 확장돼면서 이뤄낸 현상이라고 예측한다.
#
# 아마 좀 더 유의미한 결론을 내리기 위해서는 2021년 5월 이후에 데이터를 보고 판단할수 있을거라고 생각한다.
#
# 그래도 이 분석을 통해 백신 접종을 시작하면서 일차적으로 확진자/입원자/사망자 수가 내려간것에 대한 상관관계를 관찰할 수 있고 백신 접종에 효과에 대해 기대하게 되는 자료인거 같다.

# %% [markdown]
# 6. 회고

# %% [markdown]
# 두가지 큰 아쉬움이 남는다.
#
# 1. 원래는 이 데이터를 사용하여 백신 접종률이 올라갈수록 확진자/입원자/사망자 수에 어떤 영향을 끼칠지 예측하는 Regression모델을 만들려고 했다. 하지만 시간열 데이터를 다루는 부분에서 미흡했고 시간열 데이터로 Regression을 돌리는데 실패했다.
#
# 2. 2020년 부터 2021년 3월 까지만 보면 백신접종에 효과가 보다 뚜렷하게 나오나 delta variant라는 예측하지 못한 변수로 확진자 수가 2021년 5월 기준 더 높아져서 백신에 효과에 대해 정확히 판단하기 어려워졌다. 백신 접종을 더 오래 지속하고 delta variant에 effect도 좀 더 오래 관찰해서 다시 이 분석을 하면 좀 더 유의미한 결론들이 나오지 않을까 싶다.
